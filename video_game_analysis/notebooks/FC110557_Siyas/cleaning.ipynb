# %%
import pandas as pd
import numpy as np

# Load raw dataset
df = pd.read_csv('/workspaces/ML_01_video_game_prediction/video_game_analysis/src/data/Video_Games_Sales_as_at_22_Dec_2016.csv')

# Preview first few rows
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          51.0          8       322.0  Nintendo      E
# 1           NaN        NaN         NaN       NaN    NaN
# 2          73.0        8.3       709.0  Nintendo      E
# 3          73.0          8       192.0  Nintendo      E
# 4           NaN        NaN         NaN       NaN    NaN

# %%
#Checking for missing values
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       10015 non-null  object
#  13  User_Count       7590 non-null   float64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# dtypes: float64(9), object(7)
# memory usage: 2.0+ MB
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         6704
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %%
#Drop rows where the target or essential info is missing
#Since global Sales null values are 0, didnt include
df = df.dropna(subset=['Year_of_Release']) 

# Convert year to integer
df['Year_of_Release'] = df['Year_of_Release'].astype(int)

# %%
# Convert 'tbd' to NaN and then to float
df['User_Score'] = pd.to_numeric(df['User_Score'], errors='coerce')

# %%
# Fill numeric scores & counts with median (fixed version)
median_values = {
    'Critic_Score': df['Critic_Score'].median(),
    'Critic_Count': df['Critic_Count'].median(),
    'User_Score': df['User_Score'].median(),
    'User_Count': df['User_Count'].median()
}
df.fillna(median_values, inplace=True)

# Fill categories with 'Unknown' (fixed version)
df['Publisher'] = df['Publisher'].fillna('Unknown')
df['Developer'] = df['Developer'].fillna('Unknown')
df['Rating'] = df['Rating'].fillna('Unknown')

# %%
#Feature Engineering
# User_Score is on a 10 scale, so convert it to 100 before averaging
df['Total_Rating'] = (df['Critic_Score'] + (df['User_Score'] * 10)) / 2

# %%
#Drop Unnecessary Columns
df.drop(columns=['Name', 'Developer'], inplace=True)

# %%
#Handle Categorical Variables
top_publishers = df['Publisher'].value_counts().nlargest(30).index
df['Publisher'] = df['Publisher'].apply(lambda x: x if x in top_publishers else 'Other')

#One-hot encode categorical columns
df = pd.get_dummies(df, columns=['Platform', 'Genre', 'Publisher', 'Rating'], drop_first=True)

# %%
#Confirm Everything is Numeric
df.info()  # Make sure all columns are now numeric
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16450 entries, 0 to 16718
# Data columns (total 90 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Year_of_Release                                   16450 non-null  int64
#  1   NA_Sales                                          16450 non-null  float64
#  2   EU_Sales                                          16450 non-null  float64
#  3   JP_Sales                                          16450 non-null  float64
#  4   Other_Sales                                       16450 non-null  float64
#  5   Global_Sales                                      16450 non-null  float64
#  6   Critic_Score                                      16450 non-null  float64
#  7   Critic_Count                                      16450 non-null  float64
#  8   User_Score                                        16450 non-null  float64
#  9   User_Count                                        16450 non-null  float64
#  10  Total_Rating                                      16450 non-null  float64
#  11  Platform_3DO                                      16450 non-null  bool
#  12  Platform_3DS                                      16450 non-null  bool
#  13  Platform_DC                                       16450 non-null  bool
#  14  Platform_DS                                       16450 non-null  bool
#  15  Platform_GB                                       16450 non-null  bool
#  16  Platform_GBA                                      16450 non-null  bool
#  17  Platform_GC                                       16450 non-null  bool
#  18  Platform_GEN                                      16450 non-null  bool
#  19  Platform_GG                                       16450 non-null  bool
#  20  Platform_N64                                      16450 non-null  bool
#  21  Platform_NES                                      16450 non-null  bool
#  22  Platform_NG                                       16450 non-null  bool
#  23  Platform_PC                                       16450 non-null  bool
#  24  Platform_PCFX                                     16450 non-null  bool
#  25  Platform_PS                                       16450 non-null  bool
#  26  Platform_PS2                                      16450 non-null  bool
#  27  Platform_PS3                                      16450 non-null  bool
#  28  Platform_PS4                                      16450 non-null  bool
#  29  Platform_PSP                                      16450 non-null  bool
#  30  Platform_PSV                                      16450 non-null  bool
#  31  Platform_SAT                                      16450 non-null  bool
#  32  Platform_SCD                                      16450 non-null  bool
#  33  Platform_SNES                                     16450 non-null  bool
#  34  Platform_TG16                                     16450 non-null  bool
#  35  Platform_WS                                       16450 non-null  bool
#  36  Platform_Wii                                      16450 non-null  bool
#  37  Platform_WiiU                                     16450 non-null  bool
#  38  Platform_X360                                     16450 non-null  bool
#  39  Platform_XB                                       16450 non-null  bool
#  40  Platform_XOne                                     16450 non-null  bool
#  41  Genre_Adventure                                   16450 non-null  bool
#  42  Genre_Fighting                                    16450 non-null  bool
#  43  Genre_Misc                                        16450 non-null  bool
#  44  Genre_Platform                                    16450 non-null  bool
#  45  Genre_Puzzle                                      16450 non-null  bool
#  46  Genre_Racing                                      16450 non-null  bool
#  47  Genre_Role-Playing                                16450 non-null  bool
#  48  Genre_Shooter                                     16450 non-null  bool
#  49  Genre_Simulation                                  16450 non-null  bool
#  50  Genre_Sports                                      16450 non-null  bool
#  51  Genre_Strategy                                    16450 non-null  bool
#  52  Publisher_Acclaim Entertainment                   16450 non-null  bool
#  53  Publisher_Activision                              16450 non-null  bool
#  54  Publisher_Atari                                   16450 non-null  bool
#  55  Publisher_Capcom                                  16450 non-null  bool
#  56  Publisher_Codemasters                             16450 non-null  bool
#  57  Publisher_D3Publisher                             16450 non-null  bool
#  58  Publisher_Deep Silver                             16450 non-null  bool
#  59  Publisher_Disney Interactive Studios              16450 non-null  bool
#  60  Publisher_Eidos Interactive                       16450 non-null  bool
#  61  Publisher_Electronic Arts                         16450 non-null  bool
#  62  Publisher_Idea Factory                            16450 non-null  bool
#  63  Publisher_Konami Digital Entertainment            16450 non-null  bool
#  64  Publisher_Majesco Entertainment                   16450 non-null  bool
#  65  Publisher_Microsoft Game Studios                  16450 non-null  bool
#  66  Publisher_Midway Games                            16450 non-null  bool
#  67  Publisher_Namco Bandai Games                      16450 non-null  bool
#  68  Publisher_Nintendo                                16450 non-null  bool
#  69  Publisher_Nippon Ichi Software                    16450 non-null  bool
#  70  Publisher_Other                                   16450 non-null  bool
#  71  Publisher_Sega                                    16450 non-null  bool
#  72  Publisher_Sony Computer Entertainment             16450 non-null  bool
#  73  Publisher_Square Enix                             16450 non-null  bool
#  74  Publisher_THQ                                     16450 non-null  bool
#  75  Publisher_Take-Two Interactive                    16450 non-null  bool
#  76  Publisher_Tecmo Koei                              16450 non-null  bool
#  77  Publisher_Ubisoft                                 16450 non-null  bool
#  78  Publisher_Unknown                                 16450 non-null  bool
#  79  Publisher_Vivendi Games                           16450 non-null  bool
#  80  Publisher_Warner Bros. Interactive Entertainment  16450 non-null  bool
#  81  Publisher_Zoo Digital Publishing                  16450 non-null  bool
#  82  Rating_E                                          16450 non-null  bool
#  83  Rating_E10+                                       16450 non-null  bool
#  84  Rating_EC                                         16450 non-null  bool
#  85  Rating_K-A                                        16450 non-null  bool
#  86  Rating_M                                          16450 non-null  bool
#  87  Rating_RP                                         16450 non-null  bool
#  88  Rating_T                                          16450 non-null  bool
#  89  Rating_Unknown                                    16450 non-null  bool
# dtypes: bool(79), float64(10), int64(1)
# memory usage: 2.7 MB

# %%
#Save Cleaned Dataset
df.to_csv('/workspaces/ML_01_video_game_prediction/video_game_analysis/notebooks/FC110557_Siyas/vgsales_cleaned.csv', index=False)
